# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Data_Exercise2.csv")

# %%
df.plot(kind='scatter', x='Salary', y='Working Time', color=['red' if i == 1 else 'blue' for i in df['Loan Decision']])
plt.axline((4,2),(9,0),color='green')
